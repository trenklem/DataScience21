# %% [markdown]
# # Exercise: Geographical Cluster Analysis of Taxi Rides
# Using the NY Taxi data set (see Use Case Block I) and the use case from the lecture...

# %%
import pandas as pd
import numpy as np
import folium

# %%
# we load the data we have saved after wrangling and pre-processing in block I
train=pd.read_csv('../..//DATA/train_cleaned.csv')

# %%
#select only the culumns with the ride coordinates
coordinates = train[ ['pickup_latitude','pickup_longitude','dropoff_latitude' , 'dropoff_longitude' ] ]

# %% [markdown]
# ## Clustering approach from the lecture
# we will be using simple K-Means:
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %%
from sklearn.cluster import KMeans

# %%
#define number of clusters and create instance
clusters=100
myKMeans=KMeans(n_clusters=clusters, n_jobs=-1)#parallelize to all cores

# %%
#train model
myKMeans.fit(coordinates.to_numpy()[:100000,:])#use only subset of the data to make it faster
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=100, n_init=10, n_jobs=-1, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
#get cluster centers
centers=myKMeans.cluster_centers_

# %%
#draw cluster centers on map: green: start, red: end
cluster_map = folium.Map(location = [40.730610,-73.935242],zoom_start = 12,)
for i in range(clusters):
    folium.CircleMarker([centers[i,0], centers[i,1]], radius=3,                
                        color="green", 
                        fill_opacity=0.9
                       ).add_to(cluster_map)
    folium.CircleMarker([centers[i,2], centers[i,3]], radius=3,                
                        color="red", 
                        fill_opacity=0.9
                       ).add_to(cluster_map)
    folium.PolyLine([ [centers[i,0],centers[i,1]] , [centers[i,2],centers[i,3]]  ], color="black", weight=2.5, opacity=1).add_to(cluster_map)

# %%
cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Exercise 1
# Write a function ```show_cluster(cluster_number,...)``` that draws the cluster centers and all start and end points of a given cluster in the map.
# * use the ```predict()``` method to map all data in ```train_data``` to a cluster center
# * use ```folium.CircleMarker``` to draw all members of a given cluster

# %%
# first, use the model to predict the cluster assignment of all data points
predictions = myKMeans.predict(coordinates.to_numpy())

# %%
#result gives a cluster number per coordiante
# look at the first 10 entries
predictions[:10]
# Out:
# array([19, 74, 67, 34, 26, 13, 84, 70, 68, 78], dtype=int32)

# %%
def show_cluster(cluster_number, predictions, centers):
    #get coordinates of the target cluster
    #coordinates were all coordinate collumns from the train data
    cluster_coord = coordinates.to_numpy()[predictions==cluster_number]
    
    #get number of entries:
    entries = np.shape(cluster_coord)[0]
    print("number of cluster enries:" , entries)
    
    #create map
    cluster_map = folium.Map(location = [40.730610,-73.935242],zoom_start = 12,)
    
    
    for i in range(entries):
        folium.CircleMarker([cluster_coord[i,0], cluster_coord[i,1]], radius=3,                
                        color="green", 
                        fill_opacity=0.9
                       ).add_to(cluster_map)
        folium.CircleMarker([cluster_coord[i,2], cluster_coord[i,3]], radius=3,                
                        color="red", 
                        fill_opacity=0.9
                       ).add_to(cluster_map)
        
    #plot centers
    folium.PolyLine([ [centers[cluster_number,0],centers[cluster_number,1]] , [centers[cluster_number,2],centers[cluster_number,3]]  ], color="black", weight=2.5, opacity=1).add_to(cluster_map)
    
    return cluster_map

# %%
show_cluster(25,predictions,centers)
# Out:
# number of cluster enries: 15
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Exercise 2
# Write a function ```cluster_var(cluster_number,...)``` that computes the intra- and extra cluster variance for a given cluster. Apply it to all clusters and compare the results for k=100 and k=10.

# %%
def compute_var(predictions, centers):
    #get coordinates of the target cluster
    #coordinates were all coordinate collumns from the train data
    np_coord = coordinates.to_numpy()

    for i in range(centers.shape[0]): #iter over all clusters
        cluster_coord = np_coord[predictions==i] #get coordinates of Cluster i
        extra_dist = np.linalg.norm(centers-centers[i],2,axis=1)
        intra_dist = np.linalg.norm(cluster_coord-centers[i],2,axis=1)
        print(i,"#menbers:",cluster_coord.shape[0],"Intra-Var:",np.var(intra_dist),"Extra-Var:",np.var(extra_dist),"Realtion (extra/intra):",np.var(extra_dist)/np.var(intra_dist))

# %%
compute_var(predictions,centers)
# Out:
# 0 #menbers: 9765 Intra-Var: 4.526614677789634e-05 Extra-Var: 0.06449596542271852 Realtion (extra/intra): 1424.8167784012087
# 1 #menbers: 11155 Intra-Var: 1.5118747475762482e-05 Extra-Var: 0.06287203312875357 Realtion (extra/intra): 4158.547738795588
# 2 #menbers: 5007 Intra-Var: 3.884499007968066e-05 Extra-Var: 0.05614910942428595 Realtion (extra/intra): 1445.4659226095894
# 3 #menbers: 2156 Intra-Var: 0.00022491536435421828 Extra-Var: 0.04445086850173302 Realtion (extra/intra): 197.633757166218
# 4 #menbers: 29 Intra-Var: 0.003817589578064666 Extra-Var: 0.010602724190484747 Realtion (extra/intra): 2.7773347484513558
# 5 #menbers: 2324 Intra-Var: 7.309708027644322e-05 Extra-Var: 0.055335521083588295 Realtion (extra/intra): 757.01410883057
# 6 #menbers: 875 Intra-Var: 0.0007255534715479549 Extra-Var: 0.03757487516593931 Realtion (extra/intra): 51.78787868766449
# 7 #menbers: 97 Intra-Var: 0.004146910393064846 Extra-Var: 0.03736133724622024 Realtion (extra/intra): 9.00943924631265
# 8 #menbers: 1749 Intra-Var: 0.0001691964211561768 Extra-Var: 0.04284175424449822 Realtion (extra/intra): 253.2072129643518
# 9 #menbers: 1241 Intra-Var: 0.00014749767602330232 Extra-Var: 0.05036226005912473 Realtion (extra/intra): 341.4444309696668
# 10 #menbers: 53 Intra-Var: 0.0068374266094820045 Extra-Var: 0.016039829032386668 Realtion (extra/intra): 2.3458868297237676
# 11 #menbers: 3638 Intra-Var: 4.081639701515588e-05 Extra-Var: 0.06327116607150898 Realtion (extra/intra): 1550.1408918581233
# 12 #menbers: 8963 Intra-Var: 1.1210128050546118e-05 Extra-Var: 0.06492668720555105 Realtion (extra/intra): 5791.788185897488
# 13 #menbers: 9213 Intra-Var: 1.4738102301282171e-05 Extra-Var: 0.06342012858004907 Realtion (extra/intra): 4303.140749303369
# 14 #menbers: 565 Intra-Var: 0.0006426033537691204 Extra-Var: 0.058464208406615994 Realtion (extra/intra): 90.98024164315439
# 15 #menbers: 3381 Intra-Var: 3.591952173306198e-05 Extra-Var: 0.06064100628003058 Realtion (extra/intra): 1688.2464842012027
# 16 #menbers: 12584 Intra-Var: 1.390142646681979e-05 Extra-Var: 0.061965923342478385 Realtion (extra/intra): 4457.522649951063
# 17 #menbers: 3546 Intra-Var: 2.7882114311724557e-05 Extra-Var: 0.056141434416708824 Realtion (extra/intra): 2013.5285936009914
# 18 #menbers: 1847 Intra-Var: 9.65699815535434e-05 Extra-Var: 0.050415618046085846 Realtion (extra/intra): 522.0630390007149
# 19 #menbers: 469 Intra-Var: 0.0004628533901766915 Extra-Var: 0.03842823403137239 Realtion (extra/intra): 83.02463554755998
# 20 #menbers: 639 Intra-Var: 0.00018099497053194043 Extra-Var: 0.046992610093909155 Realtion (extra/intra): 259.63489458187075
# 21 #menbers: 12310 Intra-Var: 1.04294460911021e-05 Extra-Var: 0.06279645924726716 Realtion (extra/intra): 6021.073286034057
# 22 #menbers: 479 Intra-Var: 0.001262576351573886 Extra-Var: 0.041565667512890536 Realtion (extra/intra): 32.921310034895036
# 23 #menbers: 5256 Intra-Var: 2.0093548420219392e-05 Extra-Var: 0.057262619905573436 Realtion (extra/intra): 2849.8012749182813
# 24 #menbers: 6488 Intra-Var: 2.4408424491432718e-05 Extra-Var: 0.06399161426854118 Realtion (extra/intra): 2621.7019574943083
# 25 #menbers: 15 Intra-Var: 0.01542110128510627 Extra-Var: 0.019762333539859397 Realtion (extra/intra): 1.2815124662300155
# 26 #menbers: 10427 Intra-Var: 1.0190946580924262e-05 Extra-Var: 0.05823732107736999 Realtion (extra/intra): 5714.613516508904
# 27 #menbers: 8148 Intra-Var: 1.742227897224421e-05 Extra-Var: 0.06504533333416992 Realtion (extra/intra): 3733.457226680561
# 28 #menbers: 9753 Intra-Var: 2.503018421996586e-05 Extra-Var: 0.06278950505701433 Realtion (extra/intra): 2508.5514555234054
# 29 #menbers: 253 Intra-Var: 0.0005789556977535723 Extra-Var: 0.046517507366467106 Realtion (extra/intra): 80.3472658563711
# 30 #menbers: 405 Intra-Var: 0.000764242538328514 Extra-Var: 0.03797990718077106 Realtion (extra/intra): 49.69614392812715
# 31 #menbers: 35 Intra-Var: 0.0030272809819285535 Extra-Var: 0.021331611681727262 Realtion (extra/intra): 7.046459119277983
# 32 #menbers: 2373 Intra-Var: 0.00010624338889450043 Extra-Var: 0.06260403450419659 Realtion (extra/intra): 589.2511068746342
# 33 #menbers: 997 Intra-Var: 0.00020683175937464507 Extra-Var: 0.04235565212958166 Realtion (extra/intra): 204.78311579248654
# 34 #menbers: 10496 Intra-Var: 1.1963746679421623e-05 Extra-Var: 0.0641990880296067 Realtion (extra/intra): 5366.135688917006
# 35 #menbers: 97 Intra-Var: 0.0021426012473255047 Extra-Var: 0.06326944294750078 Realtion (extra/intra): 29.529266365580934
# 36 #menbers: 807 Intra-Var: 0.0001134269352815506 Extra-Var: 0.048056595056827696 Realtion (extra/intra): 423.6788637332099
# 37 #menbers: 5 Intra-Var: 0.00875820385998005 Extra-Var: 0.01502300440066737 Realtion (extra/intra): 1.715306544680223
# 38 #menbers: 4831 Intra-Var: 2.4591565343053014e-05 Extra-Var: 0.06115074942422836 Realtion (extra/intra): 2486.6554272236726
# 39 #menbers: 1978 Intra-Var: 9.520864096652472e-05 Extra-Var: 0.06040529356468361 Realtion (extra/intra): 634.4517992429077
# 40 #menbers: 9855 Intra-Var: 1.4468240244039947e-05 Extra-Var: 0.06301006400776836 Realtion (extra/intra): 4355.06066701683
# 41 #menbers: 11282 Intra-Var: 2.4318991088425883e-05 Extra-Var: 0.05575739542851001 Realtion (extra/intra): 2292.751176468278
# 42 #menbers: 5473 Intra-Var: 2.5323111993771544e-05 Extra-Var: 0.057025932907565344 Realtion (extra/intra): 2251.932263364448
# 43 #menbers: 1418 Intra-Var: 0.00024574194985357357 Extra-Var: 0.04611860187879083 Realtion (extra/intra): 187.67085516441455
# 44 #menbers: 11405 Intra-Var: 1.4475707796386798e-05 Extra-Var: 0.06437685275733619 Realtion (extra/intra): 4447.233507532181
# 45 #menbers: 1510 Intra-Var: 0.00011362150627322233 Extra-Var: 0.04947498553038513 Realtion (extra/intra): 435.4368037633128
# 46 #menbers: 797 Intra-Var: 0.00035431689925784557 Extra-Var: 0.04921067925932375 Realtion (extra/intra): 138.88888552140966
# 47 #menbers: 835 Intra-Var: 0.0004090833483043936 Extra-Var: 0.046310888614836815 Realtion (extra/intra): 113.20648666534694
# 48 #menbers: 6666 Intra-Var: 2.2448545806751357e-05 Extra-Var: 0.058211583657659716 Realtion (extra/intra): 2593.111560934726
# 49 #menbers: 12380 Intra-Var: 1.2195322669382984e-05 Extra-Var: 0.0638383601436121 Realtion (extra/intra): 5234.659375096467
# 50 #menbers: 4790 Intra-Var: 0.0001001938244304423 Extra-Var: 0.0654809181440837 Realtion (extra/intra): 653.5424564968334
# 51 #menbers: 102 Intra-Var: 0.005462702890284772 Extra-Var: 0.050693941232650516 Realtion (extra/intra): 9.280010692656914
# 52 #menbers: 872 Intra-Var: 0.00028250063426951444 Extra-Var: 0.045123518872006774 Realtion (extra/intra): 159.72891171974334
# 53 #menbers: 1624 Intra-Var: 0.0001320715960390822 Extra-Var: 0.06313328695772996 Realtion (extra/intra): 478.0231999244392
# 54 #menbers: 1642 Intra-Var: 8.661441843672388e-05 Extra-Var: 0.05744134956303417 Realtion (extra/intra): 663.1846129059669
# 55 #menbers: 9972 Intra-Var: 1.168522579357272e-05 Extra-Var: 0.06455858988715636 Realtion (extra/intra): 5524.804657404723
# 56 #menbers: 9550 Intra-Var: 1.2082343493720411e-05 Extra-Var: 0.06093890539505565 Realtion (extra/intra): 5043.63291994865
# 57 #menbers: 4466 Intra-Var: 2.767807626046714e-05 Extra-Var: 0.06045279072252207 Realtion (extra/intra): 2184.1399002454286
# 58 #menbers: 679 Intra-Var: 0.00020485815187037813 Extra-Var: 0.045701018107674914 Realtion (extra/intra): 223.0861583511295
# 59 #menbers: 1974 Intra-Var: 0.000178307724714733 Extra-Var: 0.05892288148783261 Realtion (extra/intra): 330.45613465205076
# 60 #menbers: 776 Intra-Var: 0.0002046521850881104 Extra-Var: 0.05858463402651612 Realtion (extra/intra): 286.26439537546713
# 61 #menbers: 2976 Intra-Var: 5.5534144602658414e-05 Extra-Var: 0.05310201543730822 Realtion (extra/intra): 956.204796476981
# 62 #menbers: 18 Intra-Var: 0.011453763096383456 Extra-Var: 0.0196168103177246 Realtion (extra/intra): 1.7126956575449548
# 63 #menbers: 3947 Intra-Var: 5.661121647116129e-05 Extra-Var: 0.05113640089474798 Realtion (extra/intra): 903.2909745155844
# 64 #menbers: 51 Intra-Var: 0.007074715405160513 Extra-Var: 0.025535451475819464 Realtion (extra/intra): 3.6093962814664073
# 65 #menbers: 284 Intra-Var: 0.0005797480218729985 Extra-Var: 0.03756009069605881 Realtion (extra/intra): 64.78692342013174
# 66 #menbers: 1538 Intra-Var: 0.00011338505666856046 Extra-Var: 0.05533071837585173 Realtion (extra/intra): 487.9895111539323
# 67 #menbers: 11573 Intra-Var: 1.4320924525831123e-05 Extra-Var: 0.06289815806712143 Realtion (extra/intra): 4392.045915308747
# 68 #menbers: 6817 Intra-Var: 1.846812386335423e-05 Extra-Var: 0.06525757152318333 Realtion (extra/intra): 3533.524683179761
# 69 #menbers: 627 Intra-Var: 0.00027979222214242756 Extra-Var: 0.06120687733219001 Realtion (extra/intra): 218.75832309960637
# 70 #menbers: 7355 Intra-Var: 2.3813063592506122e-05 Extra-Var: 0.059465251560712265 Realtion (extra/intra): 2497.1693091780826
# 71 #menbers: 10718 Intra-Var: 1.1102065162036433e-05 Extra-Var: 0.061451914109850014 Realtion (extra/intra): 5535.178654867307
# 72 #menbers: 728 Intra-Var: 0.000615099732251527 Extra-Var: 0.04130192145607199 Realtion (extra/intra): 67.1467069330194
# 73 #menbers: 953 Intra-Var: 0.00019581792689243337 Extra-Var: 0.04902621947441392 Realtion (extra/intra): 250.36634925332953
# 74 #menbers: 1908 Intra-Var: 7.337820721498259e-05 Extra-Var: 0.06110905861025517 Realtion (extra/intra): 832.795743172337
# 75 #menbers: 1912 Intra-Var: 9.443936340169629e-05 Extra-Var: 0.056451745466453575 Realtion (extra/intra): 597.7565226306853
# 76 #menbers: 317 Intra-Var: 0.0006617113112565065 Extra-Var: 0.05885876688324312 Realtion (extra/intra): 88.94931351782053
# 77 #menbers: 8558 Intra-Var: 1.8840271904233516e-05 Extra-Var: 0.059788905159620015 Realtion (extra/intra): 3173.462966114895
# 78 #menbers: 9891 Intra-Var: 1.1602835081657695e-05 Extra-Var: 0.06340690310829687 Realtion (extra/intra): 5464.776725865342
# 79 #menbers: 278 Intra-Var: 0.0015137378227161572 Extra-Var: 0.033422979146019875 Realtion (extra/intra): 22.079767476542113
# 80 #menbers: 361 Intra-Var: 0.0003351457893507307 Extra-Var: 0.04108106946005102 Realtion (extra/intra): 122.57671367328327
# 81 #menbers: 1084 Intra-Var: 0.00014048804873282564 Extra-Var: 0.06174712642997978 Realtion (extra/intra): 439.5187134202989
# 82 #menbers: 4031 Intra-Var: 3.395782301321498e-05 Extra-Var: 0.06103441087902505 Realtion (extra/intra): 1797.3593553177122
# 83 #menbers: 8559 Intra-Var: 1.2861802278711138e-05 Extra-Var: 0.0592409219940014 Realtion (extra/intra): 4605.958069504536
# 84 #menbers: 11484 Intra-Var: 1.2075098230258306e-05 Extra-Var: 0.06096343099751142 Realtion (extra/intra): 5048.690274398481
# 85 #menbers: 1896 Intra-Var: 7.453408470052069e-05 Extra-Var: 0.05602201574385884 Realtion (extra/intra): 751.6294856099236
# 86 #menbers: 9979 Intra-Var: 1.2889344023016271e-05 Extra-Var: 0.06504359377308526 Realtion (extra/intra): 5046.307527903521
# 87 #menbers: 229 Intra-Var: 0.0006919101600893194 Extra-Var: 0.040643146400649595 Realtion (extra/intra): 58.740496591931716
# 88 #menbers: 3368 Intra-Var: 5.364248348856366e-05 Extra-Var: 0.061927394804623066 Realtion (extra/intra): 1154.4468260464807
# 89 #menbers: 726 Intra-Var: 0.00036071252664898946 Extra-Var: 0.04540643647461679 Realtion (extra/intra): 125.87984369836411
# 90 #menbers: 1 Intra-Var: 0.0 Extra-Var: 0.01598816254317069 Realtion (extra/intra): inf
# 91 #menbers: 4019 Intra-Var: 6.138245779398888e-05 Extra-Var: 0.05984174240392068 Realtion (extra/intra): 974.899744235737
# 92 #menbers: 13871 Intra-Var: 1.5357468556959178e-05 Extra-Var: 0.05847589210255985 Realtion (extra/intra): 3807.651754954219
# 93 #menbers: 430 Intra-Var: 0.00033030032728867766 Extra-Var: 0.043434865340694004 Realtion (extra/intra): 131.50112716277317
# 94 #menbers: 3199 Intra-Var: 5.05375420240259e-05 Extra-Var: 0.050141985313006315 Realtion (extra/intra): 992.1730124739439
# 95 #menbers: 7164 Intra-Var: 2.7344207395664784e-05 Extra-Var: 0.06327827897058064 Realtion (extra/intra): 2314.138349485051
# 96 #menbers: 34 Intra-Var: 0.004547304897854981 Extra-Var: 0.021206521080047936 Realtion (extra/intra): 4.66353621681522
# 97 #menbers: 1302 Intra-Var: 0.00013221524999342498 Extra-Var: 0.05197476596880669 Realtion (extra/intra): 393.1071943016511
# 98 #menbers: 1454 Intra-Var: 0.0001501017896624352 Extra-Var: 0.05903020839578293 Realtion (extra/intra): 393.2678519592359
# 99 #menbers: 3843 Intra-Var: 8.365113739419252e-05 Extra-Var: 0.048754725690257635 Realtion (extra/intra): 582.8339841992685
# /home/keuper/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Note: plot a Cluster with high Relation and very low relation...
